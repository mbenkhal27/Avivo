# %%
from pandas import DataFrame, read_csv
import matplotlib.pyplot as plt
import pandas as pd
Location_one=r'/Users/mbenkhal/Documents/Avivo/code and data/ArrangedData.xlsx'
Location_two=r'/Users/mbenkhal/Documents/Avivo/admission_discharge_demographic-2.xlsx'
data_one =  pd.read_excel(Location_one)
data_two =  pd.read_excel(Location_two)
data_one.head(5)
data_two.head(5)
# Out:
#    Form.Date                Program             Staff Client.Number  \
# 1 2014-09-12    Treatment - IDD Men      Qualley, Ann          4547
# 2 2014-09-26    Treatment - IDD Men      Qualley, Ann     111155997
# 3 2014-09-29  Treatment - IDD Women  Salsness, Carrie     111156277
# 4 2014-10-01  Treatment - IDD Women  Salsness, Carrie     111156358
# 5 2014-10-01  Treatment - IDD Women  Salsness, Carrie     111156017
#
#                   Reason.for.Discharge  \
# 1                    Completed program
# 2         Patient conduct (behavioral)
# 3  Patient left without staff approval
# 4  Patient left without staff approval
# 5         Transferred to other program
#
#   Any.children.living.else.where.due.to.CPS.court.order.or.action  \
# 1  Not applicable - no children/no child protect ...
# 2  Not applicable - no children/no child protect ...
# 3  Not applicable - no children/no child protect ...
# 4  Not applicable - no children/no child protect ...
# 5  Not applicable - no children/no child protect ...
#
#   CD.Treatments.used  CHSR.Dimension.1  CHSR.Dimension.2  CHSR.Dimension.3  \
# 1                NaN        No problem        No problem  Moderate problem
# 2                NaN        No problem        No problem     Minor problem
# 3                NaN  Moderate problem     Minor problem  Moderate problem
# 4                NaN        No problem   Serious problem  Moderate problem
# 5                NaN     Minor problem  Moderate problem  Moderate problem
#
#      ...     Total.Charges..dollars.only.            Victim.of.abuse  \
# 1    ...                              NaN                         No
# 2    ...                           9270.0                         No
# 3    ...                              NaN  Yes, physical and sexual
# 4    ...                              NaN                         No
# 5    ...                              NaN  Yes, physical and sexual
#
#   Were.treatment.services.respectful.of.culture  \
# 1                                       Unknown
# 2                                       Unknown
# 3                                       Unknown
# 4                                       Unknown
# 5                                       Unknown
#
#         Where.client.has.been.living.in.past.30.days  \
# 1  Independent living - including on own, self su...
# 2  Independent living - including on own, self su...
# 3  Independent living - including on own, self su...
# 4  Dependent living - dependent children and/or a...
# 5  Dependent living - dependent children and/or a...
#
#   Will.client.be.living.in.environment..conducive.to.recovery Date.of.Birth  \
# 1                                                Yes             1964-02-10
# 2                                            Unknown             1985-03-28
# 3                                            Unknown             1980-07-20
# 4                                            Unknown             1991-08-14
# 5                                            Unknown             1966-06-13
#
#     Age     Sex                       Race  Form.Flag
# 1  53.0    Male  Black or African American  admission
# 2  32.0    Male  Black or African American  admission
# 3  37.0  Female                      White  admission
# 4  26.0  Female  Black or African American  admission
# 5  51.0  Female  Black or African American  admission
#
# [5 rows x 69 columns]

# %%
data_one.head(5)
# Out:
#   Client_number                          Program  \
# 0     111155778  Treatment - Family - Outpatient
# 1     111155791  Treatment - Family - Outpatient
# 2     111155800  Treatment - Family - Outpatient
# 3     111155816  Treatment - Family - Outpatient
# 4     111155822  Treatment - Family - Outpatient
#
#                                                 Code start_service_data  \
# 0  H2035 HH HQ U60944: IOP Family - IDD w/kids - ...         2014-09-02
# 1  H2035 HH HQ U60944: IOP Family - IDD w/kids - ...         2014-09-02
# 2  H2035 HH HQ U60944: IOP Family - IDD w/kids - ...         2014-09-02
# 3  H2035 HH HQ U60945: IOP Family - IDD w/kids - ...         2014-11-04
# 4  H2035 HH HQ U60944: IOP Family - IDD w/kids - ...         2014-09-02
#
#   end_service_data data_birth  gender                                   race  \
# 0       2014-10-10 1990-08-01  Female                             Other Race
# 1       2014-10-13 1994-06-13  Female  American Indian or Alaska NativeAsian
# 2       2014-09-23 1985-02-11  Female                                  White
# 3       2014-11-04 1976-12-24  Female                                  White
# 4       2014-09-22 1982-12-18  Female                                  White
#
#    number_hours  year
# 0          62.0  2014
# 1          92.0  2014
# 2          46.0  2014
# 3           1.0  2014
# 4          31.0  2014

# %%
data_discharge = data_two[data_two['Form.Flag'] == 'discharge']

data_discharge.head(5)
# Out:
#       Form.Date                Program             Staff Client.Number  \
# 1790 2014-09-12    Treatment - IDD Men      Qualley, Ann          4547
# 1791 2014-09-26    Treatment - IDD Men      Qualley, Ann     111155997
# 1792 2014-09-29  Treatment - IDD Women  Salsness, Carrie     111156277
# 1793 2014-10-01  Treatment - IDD Women  Salsness, Carrie     111156358
# 1794 2014-10-01  Treatment - IDD Women  Salsness, Carrie     111156017
#
#                      Reason.for.Discharge  \
# 1790                    Completed program
# 1791         Patient conduct (behavioral)
# 1792  Patient left without staff approval
# 1793  Patient left without staff approval
# 1794         Transferred to other program
#
#      Any.children.living.else.where.due.to.CPS.court.order.or.action  \
# 1790  Not applicable - no children/no child protect ...
# 1791  Not applicable - no children/no child protect ...
# 1792  Not applicable - no children/no child protect ...
# 1793  Not applicable - no children/no child protect ...
# 1794  Not applicable - no children/no child protect ...
#
#      CD.Treatments.used  CHSR.Dimension.1  CHSR.Dimension.2  CHSR.Dimension.3  \
# 1790                NaN        No problem        No problem  Moderate problem
# 1791                NaN        No problem        No problem     Minor problem
# 1792                NaN  Moderate problem     Minor problem  Moderate problem
# 1793                NaN        No problem   Serious problem  Moderate problem
# 1794                NaN     Minor problem  Moderate problem  Moderate problem
#
#         ...     Total.Charges..dollars.only.            Victim.of.abuse  \
# 1790    ...                              NaN                         No
# 1791    ...                           9270.0                         No
# 1792    ...                              NaN  Yes, physical and sexual
# 1793    ...                              NaN                         No
# 1794    ...                              NaN  Yes, physical and sexual
#
#      Were.treatment.services.respectful.of.culture  \
# 1790                                       Unknown
# 1791                                       Unknown
# 1792                                       Unknown
# 1793                                       Unknown
# 1794                                       Unknown
#
#            Where.client.has.been.living.in.past.30.days  \
# 1790  Independent living - including on own, self su...
# 1791  Independent living - including on own, self su...
# 1792  Independent living - including on own, self su...
# 1793  Dependent living - dependent children and/or a...
# 1794  Dependent living - dependent children and/or a...
#
#      Will.client.be.living.in.environment..conducive.to.recovery  \
# 1790                                                Yes
# 1791                                            Unknown
# 1792                                            Unknown
# 1793                                            Unknown
# 1794                                            Unknown
#
#      Date.of.Birth   Age     Sex                       Race  Form.Flag
# 1790    1964-02-10  53.0    Male  Black or African American  discharge
# 1791    1985-03-28  32.0    Male  Black or African American  discharge
# 1792    1980-07-20  37.0  Female                      White  discharge
# 1793    1991-08-14  26.0  Female  Black or African American  discharge
# 1794    1966-06-13  51.0  Female  Black or African American  discharge
#
# [5 rows x 69 columns]

# %%
data_one.shape[0]
data_one["end_service_data"]=pd.to_datetime(data_one["end_service_data"])
data_one["Reason.discharge"] ='not found'
data_one["CHSR Dimension 1"] = 'not found'
data_one["CHSR Dimension 2"] = 'not found'
data_one["CHSR Dimension 3"] = 'not found'
data_one["CHSR Dimension 4"] = 'not found'
data_one["CHSR Dimension 5"] = 'not found'
data_one["CHSR Dimension 6"]= 'not found'

data_one["Disabilities"] = 'not found'
data_one['number_of_children'] ='not found'
data_one["DSM CD Diagnosis"] ='not found'
data_one["DSM CD Diagnosis (Secondary)"] ='not found'
data_one["Enrolled in school or job training"] ='not found'

# %%
data_discharge.shape[0]
data_discharge["Form.Date"] = pd.to_datetime(data_discharge["Form.Date"])
data_one.head(5)
# Out:
# /Users/mbenkhal/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   Client_number                          Program  \
# 0     111155778  Treatment - Family - Outpatient
# 1     111155791  Treatment - Family - Outpatient
# 2     111155800  Treatment - Family - Outpatient
# 3     111155816  Treatment - Family - Outpatient
# 4     111155822  Treatment - Family - Outpatient
#
#                                                 Code start_service_data  \
# 0  H2035 HH HQ U60944: IOP Family - IDD w/kids - ...         2014-09-02
# 1  H2035 HH HQ U60944: IOP Family - IDD w/kids - ...         2014-09-02
# 2  H2035 HH HQ U60944: IOP Family - IDD w/kids - ...         2014-09-02
# 3  H2035 HH HQ U60945: IOP Family - IDD w/kids - ...         2014-11-04
# 4  H2035 HH HQ U60944: IOP Family - IDD w/kids - ...         2014-09-02
#
#   end_service_data data_birth  gender                                   race  \
# 0       2014-10-10 1990-08-01  Female                             Other Race
# 1       2014-10-13 1994-06-13  Female  American Indian or Alaska NativeAsian
# 2       2014-09-23 1985-02-11  Female                                  White
# 3       2014-11-04 1976-12-24  Female                                  White
# 4       2014-09-22 1982-12-18  Female                                  White
#
#    number_hours  year                ...                 CHSR Dimension 2  \
# 0          62.0  2014                ...                        not found
# 1          92.0  2014                ...                        not found
# 2          46.0  2014                ...                        not found
# 3           1.0  2014                ...                        not found
# 4          31.0  2014                ...                        not found
#
#   CHSR Dimension 3 CHSR Dimension 4 CHSR Dimension 5 CHSR Dimension 6  \
# 0        not found        not found        not found        not found
# 1        not found        not found        not found        not found
# 2        not found        not found        not found        not found
# 3        not found        not found        not found        not found
# 4        not found        not found        not found        not found
#
#   Disabilities number_of_children DSM CD Diagnosis  \
# 0    not found          not found        not found
# 1    not found          not found        not found
# 2    not found          not found        not found
# 3    not found          not found        not found
# 4    not found          not found        not found
#
#   DSM CD Diagnosis (Secondary) Enrolled in school or job training
# 0                    not found                          not found
# 1                    not found                          not found
# 2                    not found                          not found
# 3                    not found                          not found
# 4                    not found                          not found
#
# [5 rows x 22 columns]

# %%
for index_2, row_2 in data_one.iterrows():
    
    for index_1, row_1 in data_discharge.iterrows():
    
        if(row_1[3]== row_2[0] and row_1[1] == row_2[1] and row_1[0].year == row_2[4].year):
            data_one.loc[index_2, "Reason.discharge"] = data_discharge["Reason.for.Discharge"][index_1]
            data_one.loc[index_2, "CHSR Dimension 1"] = data_discharge["CHSR.Dimension.1"][index_1]
            data_one.loc[index_2, "CHSR Dimension 2"] = data_discharge["CHSR.Dimension.2"][index_1]
            data_one.loc[index_2, "CHSR Dimension 3"] = data_discharge["CHSR.Dimension.3"][index_1]
            data_one.loc[index_2, "CHSR Dimension 4"] = data_discharge["CHSR.Dimension.4"][index_1]
            data_one.loc[index_2, "CHSR Dimension 5"] = data_discharge["CHSR.Dimension.5"][index_1]
            data_one.loc[index_2, "CHSR Dimension 6"] = data_discharge["CHSR.Dimension.6"][index_1]
            data_one.loc[index_2, "Disabilities"] = data_discharge["Disabilities.or.Barriers.to.Treatment"][index_1]
            data_one.loc[index_2, "DSM CD Diagnosis"] = data_discharge["DSM.CD.Diagnosis"][index_1]
            data_one.loc[index_2, "DSM CD Diagnosis (Secondary)"] = data_discharge["DSM.CD.Diagnosis..Secondary."][index_1]
            data_one.loc[index_2, "Enrolled in school or job training"] = data_discharge["Enrolled.in.school.or.job.training"][index_1]
            data_one.loc[index_2, 'number_of_children'] = data_discharge["Number.of.children"][index_1]

# %% [markdown]
# #

# %%
data_one.head(5)
# Out:
#   Client_number                          Program  \
# 0     111155778  Treatment - Family - Outpatient
# 1     111155791  Treatment - Family - Outpatient
# 2     111155800  Treatment - Family - Outpatient
# 3     111155816  Treatment - Family - Outpatient
# 4     111155822  Treatment - Family - Outpatient
#
#                                                 Code start_service_data  \
# 0  H2035 HH HQ U60944: IOP Family - IDD w/kids - ...         2014-09-02
# 1  H2035 HH HQ U60944: IOP Family - IDD w/kids - ...         2014-09-02
# 2  H2035 HH HQ U60944: IOP Family - IDD w/kids - ...         2014-09-02
# 3  H2035 HH HQ U60945: IOP Family - IDD w/kids - ...         2014-11-04
# 4  H2035 HH HQ U60944: IOP Family - IDD w/kids - ...         2014-09-02
#
#   end_service_data data_birth  gender                                   race  \
# 0       2014-10-10 1990-08-01  Female                             Other Race
# 1       2014-10-13 1994-06-13  Female  American Indian or Alaska NativeAsian
# 2       2014-09-23 1985-02-11  Female                                  White
# 3       2014-11-04 1976-12-24  Female                                  White
# 4       2014-09-22 1982-12-18  Female                                  White
#
#    number_hours  year                ...                 CHSR Dimension 2  \
# 0          62.0  2014                ...                    Minor problem
# 1          92.0  2014                ...                        not found
# 2          46.0  2014                ...                        not found
# 3           1.0  2014                ...                        not found
# 4          31.0  2014                ...                        not found
#
#   CHSR Dimension 3 CHSR Dimension 4 CHSR Dimension 5  CHSR Dimension 6  \
# 0  Serious problem  Serious problem  Serious problem  Moderate problem
# 1        not found        not found        not found         not found
# 2        not found        not found        not found         not found
# 3        not found        not found        not found         not found
# 4        not found        not found        not found         not found
#
#      Disabilities number_of_children                       DSM CD Diagnosis  \
# 0  Mental illness                Two  Cannabis Use Disorder Moderate/Severe
# 1       not found          not found                              not found
# 2       not found          not found                              not found
# 3       not found          not found                              not found
# 4       not found          not found                              not found
#
#   DSM CD Diagnosis (Secondary) Enrolled in school or job training
# 0       No Secondary Diagnosis                       Not enrolled
# 1                    not found                          not found
# 2                    not found                          not found
# 3                    not found                          not found
# 4                    not found                          not found
#
# [5 rows x 22 columns]

# %%
data_one.to_excel(r'/Users/mbenkhal/Documents/Avivo/MergedData.xlsx')

# %%
Location_one=r'/Users/mbenkhal/Documents/Avivo/MergedData.xlsx'
Data = pd.read_excel(Location_one, 'Sheet1')

Data['Status'] = "false"
Data['Expected Hours'] = ''
for index, row in Data.iterrows():
    if(row[10] == "Completed program" or row[10] == "Transferred to other program"):
        
        Data.loc[index,'Status'] = "true"
    
        
Data.head(5)
# Out:
#   Client_number                          Program  \
# 0     111155778  Treatment - Family - Outpatient
# 1     111155791  Treatment - Family - Outpatient
# 2     111155800  Treatment - Family - Outpatient
# 3     111155816  Treatment - Family - Outpatient
# 4     111155822  Treatment - Family - Outpatient
#
#                                                 Code start_service_data  \
# 0  H2035 HH HQ U60944: IOP Family - IDD w/kids - ...         2014-09-02
# 1  H2035 HH HQ U60944: IOP Family - IDD w/kids - ...         2014-09-02
# 2  H2035 HH HQ U60944: IOP Family - IDD w/kids - ...         2014-09-02
# 3  H2035 HH HQ U60945: IOP Family - IDD w/kids - ...         2014-11-04
# 4  H2035 HH HQ U60944: IOP Family - IDD w/kids - ...         2014-09-02
#
#   end_service_data data_birth  gender                                   race  \
# 0       2014-10-10 1990-08-01  Female                             Other Race
# 1       2014-10-13 1994-06-13  Female  American Indian or Alaska NativeAsian
# 2       2014-09-23 1985-02-11  Female                                  White
# 3       2014-11-04 1976-12-24  Female                                  White
# 4       2014-09-22 1982-12-18  Female                                  White
#
#    number_hours  year      ...       CHSR Dimension 4 CHSR Dimension 5  \
# 0          62.0  2014      ...        Serious problem  Serious problem
# 1          92.0  2014      ...              not found        not found
# 2          46.0  2014      ...              not found        not found
# 3           1.0  2014      ...              not found        not found
# 4          31.0  2014      ...              not found        not found
#
#    CHSR Dimension 6    Disabilities number_of_children  \
# 0  Moderate problem  Mental illness                Two
# 1         not found       not found          not found
# 2         not found       not found          not found
# 3         not found       not found          not found
# 4         not found       not found          not found
#
#                         DSM CD Diagnosis DSM CD Diagnosis (Secondary)  \
# 0  Cannabis Use Disorder Moderate/Severe       No Secondary Diagnosis
# 1                              not found                    not found
# 2                              not found                    not found
# 3                              not found                    not found
# 4                              not found                    not found
#
#   Enrolled in school or job training Status Expected Hours
# 0                       Not enrolled   true
# 1                          not found  false
# 2                          not found  false
# 3                          not found  false
# 4                          not found  false
#
# [5 rows x 24 columns]

# %%
for index , row in Data.iterrows():
    if(row[1] == "Treatment - Relapse Men"):
        Data.loc[index ,'Expected Hours'] = '150'
    elif(row[1] == "Treatment - Family - Outpatient"):
        Data.loc[index ,'Expected Hours'] = '250'
    elif(row[1] == "Treatment - IDD Women"):
        Data.loc[index ,'Expected Hours'] = '200'
    elif(row[1] == "Treatment - IDD Men"):
        Data.loc[index ,'Expected Hours'] = '200'
    else:
        Data.loc[index ,'Expected Hours'] = '150'
Data.head(5)
# Out:
#   Client_number                          Program  \
# 0     111155778  Treatment - Family - Outpatient
# 1     111155791  Treatment - Family - Outpatient
# 2     111155800  Treatment - Family - Outpatient
# 3     111155816  Treatment - Family - Outpatient
# 4     111155822  Treatment - Family - Outpatient
#
#                                                 Code start_service_data  \
# 0  H2035 HH HQ U60944: IOP Family - IDD w/kids - ...         2014-09-02
# 1  H2035 HH HQ U60944: IOP Family - IDD w/kids - ...         2014-09-02
# 2  H2035 HH HQ U60944: IOP Family - IDD w/kids - ...         2014-09-02
# 3  H2035 HH HQ U60945: IOP Family - IDD w/kids - ...         2014-11-04
# 4  H2035 HH HQ U60944: IOP Family - IDD w/kids - ...         2014-09-02
#
#   end_service_data data_birth  gender                                   race  \
# 0       2014-10-10 1990-08-01  Female                             Other Race
# 1       2014-10-13 1994-06-13  Female  American Indian or Alaska NativeAsian
# 2       2014-09-23 1985-02-11  Female                                  White
# 3       2014-11-04 1976-12-24  Female                                  White
# 4       2014-09-22 1982-12-18  Female                                  White
#
#    number_hours  year      ...       CHSR Dimension 4 CHSR Dimension 5  \
# 0          62.0  2014      ...        Serious problem  Serious problem
# 1          92.0  2014      ...              not found        not found
# 2          46.0  2014      ...              not found        not found
# 3           1.0  2014      ...              not found        not found
# 4          31.0  2014      ...              not found        not found
#
#    CHSR Dimension 6    Disabilities number_of_children  \
# 0  Moderate problem  Mental illness                Two
# 1         not found       not found          not found
# 2         not found       not found          not found
# 3         not found       not found          not found
# 4         not found       not found          not found
#
#                         DSM CD Diagnosis DSM CD Diagnosis (Secondary)  \
# 0  Cannabis Use Disorder Moderate/Severe       No Secondary Diagnosis
# 1                              not found                    not found
# 2                              not found                    not found
# 3                              not found                    not found
# 4                              not found                    not found
#
#   Enrolled in school or job training Status Expected Hours
# 0                       Not enrolled   true            250
# 1                          not found  false            250
# 2                          not found  false            250
# 3                          not found  false            250
# 4                          not found  false            250
#
# [5 rows x 24 columns]

# %%
sum_hours_program = Data.groupby(['Program','Status']).sum()

sum_hours_program['number_hours'].head(5)
# Out:
# Program                          Status
# Treatment - Family - Outpatient  false     21133.25
#                                  true      17554.75
# Treatment - IDD Men              false     46733.00
#                                  true      29260.50
# Treatment - IDD Women            false     40162.00
# Name: number_hours, dtype: float64

# %%
count = Data.groupby(['Program','Status']).count()
count['Client_number'].head(5)
# Out:
# Program                          Status
# Treatment - Family - Outpatient  false     243
#                                  true       84
# Treatment - IDD Men              false     746
#                                  true      212
# Treatment - IDD Women            false     626
# Name: Client_number, dtype: int64

# %%
df = pd.DataFrame(columns= ["Program","Status","Avg_hours","Expected_Hours"])
df['Avg_hours']= sum_hours_program['number_hours']/count['Client_number']

names = list(df.index)
names
# Out:
# [('Treatment - Family - Outpatient', 'false'),
#  ('Treatment - Family - Outpatient', 'true'),
#  ('Treatment - IDD Men', 'false'),
#  ('Treatment - IDD Men', 'true'),
#  ('Treatment - IDD Women', 'false'),
#  ('Treatment - IDD Women', 'true'),
#  ('Treatment - Relapse Men', 'false'),
#  ('Treatment - Relapse Men', 'true'),
#  ('Treatment - Relapse Women', 'false'),
#  ('Treatment - Relapse Women', 'true')]

# %%
for i in range(0, df.shape[0]):
    temp = ' '.join(names[i])
    if("Treatment - Relapse Men" in temp):
        df.loc[names[i],'Expected_Hours'] = '150'
        df.loc[names[i],'Program'] = "Treatment - Relapse Men"
        if("true" in temp):
            print(temp)
            df.loc[names[i],'Status'] = 'completed'
        elif("false" in temp):
            print("not"+ temp)
            df.loc[names[i],'Status'] = 'not completed'
            
    elif("Treatment - Family - Outpatient" in temp):
        df.loc[names[i],'Expected_Hours'] = '250'
        df.loc[names[i],'Program'] = "Treatment - Family - Outpatient"
        if("true" in temp):
            df.loc[names[i],'Status'] = 'completed'
        elif("false" in temp):
            df.loc[names[i],'Status'] = ' not completed' 
    elif("Treatment - IDD Women" in temp):
        df.loc[names[i],'Expected_Hours'] = '200'
        df.loc[names[i],'Program'] = "Treatment - IDD Women"
        if("true" in temp):
            df.loc[names[i],'Status'] = 'completed'
        elif("false" in temp):
            df.loc[names[i],'Status'] = ' not completed' 
    elif("Treatment - IDD Men" in temp):
        df.loc[names[i],'Expected_Hours'] = '200'
        df.loc[names[i],'Program'] = "Treatment - IDD Men"
        if("true" in temp):
            df.loc[names[i],'Status'] = 'completed'
        elif("false" in temp):
            df.loc[names[i],'Status'] = ' not completed' 
    else:
        df.loc[names[i],'Expected_Hours'] = '150'
        df.loc[names[i],'Program'] = "Treatment - Relapse Women"
        if("true" in temp):
            df.loc[names[i],'Status'] = 'completed'
        elif("false" in temp):
            df.loc[names[i],'Status'] = 'not completed' 
df
# Out:
# notTreatment - Relapse Men false
# Treatment - Relapse Men true
#                                                                 Program  \
# Program                         Status
# Treatment - Family - Outpatient false   Treatment - Family - Outpatient
#                                 true    Treatment - Family - Outpatient
# Treatment - IDD Men             false               Treatment - IDD Men
#                                 true                Treatment - IDD Men
# Treatment - IDD Women           false             Treatment - IDD Women
#                                 true              Treatment - IDD Women
# Treatment - Relapse Men         false           Treatment - Relapse Men
#                                 true            Treatment - Relapse Men
# Treatment - Relapse Women       false         Treatment - Relapse Women
#                                 true          Treatment - Relapse Women
#
#                                                 Status   Avg_hours  \
# Program                         Status
# Treatment - Family - Outpatient false    not completed   86.968107
#                                 true         completed  208.985119
# Treatment - IDD Men             false    not completed   62.644772
#                                 true         completed  138.021226
# Treatment - IDD Women           false    not completed   64.156550
#                                 true         completed  150.256136
# Treatment - Relapse Men         false    not completed   65.176976
#                                 true         completed  138.605275
# Treatment - Relapse Women       false    not completed   57.189394
#                                 true         completed  168.769231
#
#                                        Expected_Hours
# Program                         Status
# Treatment - Family - Outpatient false             250
#                                 true              250
# Treatment - IDD Men             false             200
#                                 true              200
# Treatment - IDD Women           false             200
#                                 true              200
# Treatment - Relapse Men         false             150
#                                 true              150
# Treatment - Relapse Women       false             150
#                                 true              150

# %%
type(df["Expected_Hours"])
df['Percentage_from_expected_hours']= (df['Avg_hours']/df["Expected_Hours"].astype('int32'))*100

# %%
Data.to_excel(r'/Users/mbenkhal/Documents/Avivo/MergedData_completed.xlsx')
